# %%
import pandas as pd
import numpy as np

pd.__version__
# Out:
# '1.0.5'

# %%
data = pd.Series([0.25,0.5,0.75,1.0])
data
print(data.values) #values
print(data.index) #index
print(data[1:3])

data= pd.Series([0.25,0.5,0.75,1],index=['a','b','c','d'])
print(data)
data['b']

data= pd.Series([0.25,0.5,0.75,1],index=[2,5,3,7])
print(data)


#from dict
pop_dic={'California':3333,
         'texas': 2222,
         'New york': 1111,
         'Florida': 4444,
         'Illinois': 5555}
pop=pd.Series(pop_dic)
print(pop)
print(pop.index)

#slicing
print(pop['California':'Illinois'])
pd.Series([2,4,6])
pd.Series({2:'a',1:'b',3:'c'})
pd.Series({2:'a',1:'b',3:'c'},index=[3,2])
# Out:
# [0.25 0.5  0.75 1.  ]
# RangeIndex(start=0, stop=4, step=1)
# 1    0.50
# 2    0.75
# dtype: float64
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64
# 2    0.25
# 5    0.50
# 3    0.75
# 7    1.00
# dtype: float64
# California    3333
# texas         2222
# New york      1111
# Florida       4444
# Illinois      5555
# dtype: int64
# Index(['California', 'texas', 'New york', 'Florida', 'Illinois'], dtype='object')
# California    3333
# texas         2222
# New york      1111
# Florida       4444
# Illinois      5555
# dtype: int64
# 3    c
# 2    a
# dtype: object

# %%
area_dict=pop_dic
area=pd.Series(area_dict)
states=pd.DataFrame({'pop':pop,'area':area_dict})
print(states)
print(states.index)
print(states.columns)
states['area']

pd.DataFrame(pop,columns=['population'])
data=[{'a':i,'b':2*i} for i in range(3)]
pd.DataFrame(data)
pd.DataFrame([{'a':1,'b':2},{'b':3,'c':4}])

pd.DataFrame(np.random.rand(3,2),
             columns=['foo','bar'],
             index=['a','b','c'])

A=np.zeros(3,dtype=[('A','i8'),('B','f8')])
print(A)
pd.DataFrame(A)

ind=pd.Index([2,3,5,7,11])
print(ind)
ind[1]
ind[::2]
print(ind.size,ind.shape,ind.ndim,ind.dtype)
ind[1]=0 #error
# Out:
#              pop  area
# California  3333  3333
# Florida     4444  4444
# Illinois    5555  5555
# New york    1111  1111
# texas       2222  2222
# Index(['California', 'Florida', 'Illinois', 'New york', 'texas'], dtype='object')
# Index(['pop', 'area'], dtype='object')
# [(0, 0.) (0, 0.) (0, 0.)]
# Int64Index([2, 3, 5, 7, 11], dtype='int64')
# 5 (5,) 1 int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-b5e918053dd8> in <module>
#      25 ind[::2]
#      26 print(ind.size,ind.shape,ind.ndim,ind.dtype)
# ---> 27 ind[1]=0 #error
#
# E:\Conda\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    3908
#    3909     def __setitem__(self, key, value):
# -> 3910         raise TypeError("Index does not support mutable operations")
#    3911
#    3912     def __getitem__(self, key):
#
# ...

# %%
indA=pd.Index([1,3,5,7,9])
indB=pd.Index([2,3,5,7,11])

print(indA & indB)
print(indA | indB)
print(indA ^ indB) #diff simmetric

data=pd.Series([0.25,0.5,0.75,1],index=['a','b','c','d'])
data['b']
'a' in data # in indexes
data.keys()
print(list(data.items()))
data['e']=1.25

print(data['a':'c']) #explicit
print(data[0:2])  #implicit

#masking
data[(data >0.3) & (data<0.8)]
#fancy index
data[['a','e']]

data=pd.Series(['a','b','c'],index=[1,3,5])
print(data)

print(data[1])

print(data[1:3])

print(data.loc[1]) # loc explicit index
print(data.loc[1:3]) #explicit index

print(data.iloc[1]) # second item
print(data.iloc[1:3]) #

area=pd.Series({'Cal':1111,
                'tex':2222,
                'new york':3333,
                'florida':4444,
                'illionis':5555})
pop=pd.Series({'Cal':11114,
                'tex':22224,
                'new york':33334,
                'florida':44445,
                'illionis':55554})
data=pd.DataFrame({'area':area,'pop':pop})
print(data)
print(data['area'])
print(data.area) # dot style

data['density']=data['pop']/data['area']
print(data)
# Out:
# Int64Index([3, 5, 7], dtype='int64')
# Int64Index([1, 2, 3, 5, 7, 9, 11], dtype='int64')
# Int64Index([1, 2, 9, 11], dtype='int64')
# [('a', 0.25), ('b', 0.5), ('c', 0.75), ('d', 1.0)]
# a    0.25
# b    0.50
# c    0.75
# dtype: float64
# a    0.25
# b    0.50
# dtype: float64
# 1    a
# 3    b
# 5    c
# dtype: object
# a
# 3    b
# 5    c
# dtype: object
# a
# 1    a
# 3    b
# dtype: object
# b
# 3    b
# 5    c
# dtype: object
#           area    pop
# Cal       1111  11114
# tex       2222  22224
# new york  3333  33334
# florida   4444  44445
# illionis  5555  55554
# Cal         1111
# tex         2222
# new york    3333
# florida     4444
# illionis    5555
# Name: area, dtype: int64
# Cal         1111
# tex         2222
# new york    3333
# florida     4444
# illionis    5555
# Name: area, dtype: int64
#           area    pop    density
# Cal       1111  11114  10.003600
# tex       2222  22224  10.001800
# new york  3333  33334  10.001200
# ...

# %%
print(data.values)
print(data.T)
print(data.values[0])
print(data.T.values[0])

print(data.iloc[:3, :2])
print(data.loc[:'new york', :'pop'])

print(data.loc[data.density > 100 , ['pop','density']])
data.iloc[0,2]=90
print(data)
print(data['new york':'florida'])
print(data[1:3])

print(data[data.density>9])

rng=np.random.RandomState(42)
ser=pd.Series(rng.randint(0,10,4))
print(ser)
df=pd.DataFrame(rng.randint(0,10,(3,4)),
                columns=['A','B','C','D'])
print(df)
print(np.exp(ser))
print(np.sin(df*np.pi/4))


area=pd.Series({'Alaska':5,'Texas':60,
                'California':10},name='area')

population=pd.Series({'New york':15,'Texas':650,
                'California':100},name='population')
population /area

area.index | population.index

A=pd.Series([2,4,6], index=[0,1,2])
B=pd.Series([1,3,5], index=[1,2,3])
A+B

A.add(B,fill_value=0)
# Out:
# [[1.11100000e+03 1.11140000e+04 9.00000000e+01]
#  [2.22200000e+03 2.22240000e+04 1.00018002e+01]
#  [3.33300000e+03 3.33340000e+04 1.00012001e+01]
#  [4.44400000e+03 4.44450000e+04 1.00011251e+01]
#  [5.55500000e+03 5.55540000e+04 1.00007201e+01]]
#              Cal         tex    new york       florida     illionis
# area      1111.0   2222.0000   3333.0000   4444.000000   5555.00000
# pop      11114.0  22224.0000  33334.0000  44445.000000  55554.00000
# density     90.0     10.0018     10.0012     10.001125     10.00072
# [ 1111. 11114.    90.]
# [1111. 2222. 3333. 4444. 5555.]
#           area    pop
# Cal       1111  11114
# tex       2222  22224
# new york  3333  33334
#           area    pop
# Cal       1111  11114
# tex       2222  22224
# new york  3333  33334
# Empty DataFrame
# Columns: [pop, density]
# Index: []
#           area    pop    density
# Cal       1111  11114  90.000000
# tex       2222  22224  10.001800
# new york  3333  33334  10.001200
# ...

# %%
A = pd.DataFrame(rng.randint(0,20,(2,2)),
                 columns=list('AB'))
print(A)

B=pd.DataFrame(rng.randint(0,10,(3,3)),
               columns=list('BAC'))
print(B)
print(A+B)

fill= A.stack().mean()
print(A.add(B,fill_value=fill))

A=rng.randint(10,size=(3,4))
print(A)
print(A-A[0][0])


df=pd.DataFrame(A,columns=list('QRST'))
df - df.iloc[0]
print(df.subtract(df['R'],axis=0))


halfrow=df.iloc[0,::2]
print(halfrow)
print(df- halfrow)
# Out:
#    A   B
# 0  4  19
# 1  1   5
#    B  A  C
# 0  5  0  8
# 1  5  2  3
# 2  3  2  9
#      A     B   C
# 0  4.0  24.0 NaN
# 1  3.0  10.0 NaN
# 2  NaN   NaN NaN
#       A      B      C
# 0  4.00  24.00  15.25
# 1  3.00  10.00  10.25
# 2  9.25  10.25  16.25
# [[2 2 3 6]
#  [3 8 0 7]
#  [6 1 7 0]]
# [[ 0  0  1  4]
#  [ 1  6 -2  5]
#  [ 4 -1  5 -2]]
#    Q  R  S  T
# 0  0  0  1  4
# 1 -5  0 -8 -1
# 2  5  0  6 -1
# Q    2
# S    3
# Name: 0, dtype: int32
#      Q   R    S   T
# 0  0.0 NaN  0.0 NaN
# 1  1.0 NaN -3.0 NaN
# 2  4.0 NaN  4.0 NaN

# %%
vals1=np.array([1,None,3,4,])
print(vals1)

def print_dtype():
    for dtype in ['object','int']:
        print("dtype=", dtype)
        # %timeit np.arange(1E6,dtype=dtype).sum()
        print()

vals2=np.array([1,np.nan,3,4])
print(vals2.dtype)
vals2.sum()
np.nansum(vals2)

x=pd.Series(range(2),dtype=int)
print(x)
x[0]=None
print(x)


data=pd.Series([1,np.nan,'hello',None])
print(data.isnull())
print(data[data.notnull()])
print(data.dropna())

df=pd.DataFrame([[1,np.nan,2],
                 [2, 3, 5],
                 [np.nan,4,6]])
print(df)
print(df.dropna())
print(df.dropna(axis='columns'))

#'how' 'thresh
df[3]=np.nan
print(df)

print(df.dropna(axis='columns',how='all'))
print("Ok")
print(df.dropna(axis='columns',how='any'))


print(df.dropna(axis='rows',thresh=3))



data=pd.Series([1,np.nan,2,None,3])
data.fillna(0)

#forward fill
data.fillna(method='ffill')

#backward fill
data.fillna(method='bfill')
print(df)
df.fillna(method='ffill',axis=1)
df.fillna(method='bfill',axis=0)


##continuare da 146
# Out:
# [1 None 3 4]
# float64
# 0    0
# 1    1
# dtype: int32
# 0    NaN
# 1    1.0
# dtype: float64
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool
# 0        1
# 2    hello
# dtype: object
# 0        1
# 2    hello
# dtype: object
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6
#      0    1  2
# 1  2.0  3.0  5
#    2
# 0  2
# 1  5
# 2  6
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6
# Ok
#    2
# 0  2
# 1  5
# 2  6
#      0    1  2   3
# 1  2.0  3.0  5 NaN
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN
#      0    1  2   3
# 0  1.0  3.0  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %%
## MultiIndexing

import numpy as np
import pandas as pd

index=[('California',2000),('California',2010),
       ('New york',2000), ('New york',2010),
       ('Texas',2000), ('Texas',2010)]

population=[100000,200000,
            500000, 300000,
            90000, 99999]

pop = pd.Series(population, index=index)

print(pop[('California',2000)])
print(pop)
print(pop[('California',2000):('New york',2000)])


print(pop[[i for i in pop.index if i[1]==2010]])
print(pop.index[1][1])

#Better way

my_index=pd.MultiIndex.from_tuples(index)
print(my_index)


pop=pop.reindex(my_index)
print(pop)
print(pop[:,2010]) ## tutte le righe con qualsiasi primo indice e secondo indice pari a 2010
# Out:
# 100000
# (California, 2000)    100000
# (California, 2010)    200000
# (New york, 2000)      500000
# (New york, 2010)      300000
# (Texas, 2000)          90000
# (Texas, 2010)          99999
# dtype: int64
# (California, 2000)    100000
# (California, 2010)    200000
# (New york, 2000)      500000
# dtype: int64
# (California, 2010)    200000
# (New york, 2010)      300000
# (Texas, 2010)          99999
# dtype: int64
# 2010
# MultiIndex([('California', 2000),
#             ('California', 2010),
#             (  'New york', 2000),
#             (  'New york', 2010),
#             (     'Texas', 2000),
#             (     'Texas', 2010)],
#            )
# California  2000    100000
#             2010    200000
# New york    2000    500000
#             2010    300000
# Texas       2000     90000
#             2010     99999
# dtype: int64
# California    200000
# New york      300000
# Texas          99999
# dtype: int64

# %%
pop_df=pop.unstack() ## convert to dataframe
print(pop_df)
print(pop_df.stack()) ##convert to multiindex series

pop_df=pd.DataFrame({'total':pop,
                     'under18':[123,678,901,1000,1002,5423]})
print(pop_df)

f_u18=pop_df['under18'] / pop_df['total']
print(f_u18.unstack())
print(f_u18)
# Out:
#               2000    2010
# California  100000  200000
# New york    500000  300000
# Texas        90000   99999
# California  2000    100000
#             2010    200000
# New york    2000    500000
#             2010    300000
# Texas       2000     90000
#             2010     99999
# dtype: int64
#                   total  under18
# California 2000  100000      123
#            2010  200000      678
# New york   2000  500000      901
#            2010  300000     1000
# Texas      2000   90000     1002
#            2010   99999     5423
#                 2000      2010
# California  0.001230  0.003390
# New york    0.001802  0.003333
# Texas       0.011133  0.054231
# California  2000    0.001230
#             2010    0.003390
# New york    2000    0.001802
#             2010    0.003333
# Texas       2000    0.011133
#             2010    0.054231
# dtype: float64

# %%
df = pd.DataFrame(np.random.rand(4,2),
                 index=[['a','a','b','b'],[1,2,1,2]],
                 columns=['data1','data2'])
print(df)

pd.MultiIndex.from_arrays([['a','a','b','b'],[1,2,1,3]])
pd.MultiIndex.from_tuples([('a',1),('b',2),('b',1),('c',10)])
pd.MultiIndex.from_product([['a','b'],[1,2]])

pop.index.names=['state','year']
print(pop)

index=pd.MultiIndex.from_product([[2013,2014],[1,2]],
                                 names=['year','visit'])
columns=pd.MultiIndex.from_product([['Bob','Guido','Sue'],['HR','Temp']],
                                  names=['subject','type'])
print(columns)
data=np.round(np.random.randn(4,6),1)
data[:,::2] *=10
data+=37


health_data=pd.DataFrame(data,index=index,columns=columns)
print(health_data)
print(health_data['Guido'])
# Out:
#         data1     data2
# a 1  0.694116  0.143043
#   2  0.860501  0.078885
# b 1  0.622514  0.647382
#   2  0.740499  0.119696
# state       year
# California  2000    100000
#             2010    200000
# New york    2000    500000
#             2010    300000
# Texas       2000     90000
#             2010     99999
# dtype: int64
# MultiIndex([(  'Bob',   'HR'),
#             (  'Bob', 'Temp'),
#             ('Guido',   'HR'),
#             ('Guido', 'Temp'),
#             (  'Sue',   'HR'),
#             (  'Sue', 'Temp')],
#            names=['subject', 'type'])
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      31.0  39.0  47.0  36.4  35.0  39.4
#      2      30.0  36.2  49.0  38.4  37.0  36.5
# 2014 1      62.0  37.5  43.0  35.2  35.0  37.4
#      2      35.0  37.4  38.0  37.8  41.0  36.7
# type          HR  Temp
# year visit
# 2013 1      47.0  36.4
#      2      49.0  38.4
# 2014 1      43.0  35.2
# ...

# %%
pop['California',2000]
pop['California']
print(pop.loc['California':'New york'])
print(pop[:,2000])
print(pop[pop>90100])
print(health_data['Guido','HR'])
print(health_data.iloc[:2,:2])
print(health_data.loc[:,('Bob','HR')])
# Out:
# state       year
# California  2000    100000
#             2010    200000
# New york    2000    500000
#             2010    300000
# dtype: int64
# state
# California    100000
# New york      500000
# Texas          90000
# dtype: int64
# state       year
# California  2000    100000
#             2010    200000
# New york    2000    500000
#             2010    300000
# Texas       2010     99999
# dtype: int64
# year  visit
# 2013  1        47.0
#       2        49.0
# 2014  1        43.0
#       2        38.0
# Name: (Guido, HR), dtype: float64
# subject      Bob
# type          HR  Temp
# year visit
# 2013 1      31.0  39.0
#      2      30.0  36.2
# year  visit
# 2013  1        31.0
#       2        30.0
# 2014  1        62.0
#       2        35.0
# Name: (Bob, HR), dtype: float64

# %%
index=pd.MultiIndex.from_product([['a','c','b'],[1,2]])

data=pd.Series(np.random.rand(6),index=index)
data.index.names=['char','int']
print(data)

try:
    print(data['a':'b'])
except KeyError as e:
    print(type(e))
    print(e)
    
data=data.sort_index()
print(data)
print(data['a':'b'])

print(pop.unstack())
print(pop.unstack(level=0))
print(pop.unstack(level=1))

#reset index
pop_flat=pop.reset_index(name='population')
print(pop_flat)
pop_flat.set_index(['state','population'])

data_mean=health_data.mean(level='year')
print(data_mean)
print(data_mean.mean(axis=1,level='type'))
# Out:
# char  int
# a     1      0.358434
#       2      0.648310
# c     1      0.634581
#       2      0.802811
# b     1      0.894009
#       2      0.721195
# dtype: float64
# <class 'pandas.errors.UnsortedIndexError'>
# 'Key length (1) was greater than MultiIndex lexsort depth (0)'
# char  int
# a     1      0.358434
#       2      0.648310
# b     1      0.894009
#       2      0.721195
# c     1      0.634581
#       2      0.802811
# dtype: float64
# char  int
# a     1      0.358434
#       2      0.648310
# b     1      0.894009
#       2      0.721195
# dtype: float64
# year          2000    2010
# state
# California  100000  200000
# New york    500000  300000
# Texas        90000   99999
# state  California  New york  Texas
# year
# 2000       100000    500000  90000
# 2010       200000    300000  99999
# year          2000    2010
# state
# California  100000  200000
# New york    500000  300000
# Texas        90000   99999
#         state  year  population
# ...

# %%
##Combining dataset concat e append

def make_df(cols,ind):
    data={c: [str(c)+str(i) for i in ind]
           for c in cols}
    return pd.DataFrame(data,ind)

make_df('ABC',range(4))


x=[1,2,3]
y=[4,5,6]
z=[7,8,9]

np.concatenate([x,y,z])
x=[[1,2],[3,4]]
np.concatenate([x,x],axis=1)

#print(pd.concat(objs,axis=0,join='outer',join_axes=None,ignore_index=False,
 #               keys=None,levels=None,names=None,verify_integrity=False,copy=True))

ser1=pd.Series(['A','B','C'],index=[1,2,3])
ser2=pd.Series(['D','E','F'],index=[7,5,6])

pd.concat([ser1,ser2])
    
df1= make_df('AB',[1,2])
df2= make_df('AB',[3,4])
print(df1)
print(df2)
print(pd.concat([df1,df2]))
    
df3=make_df('AB',[0,1])
df4=make_df('CD',[0,1])

print(df3)
print(df4)
#pd.concat([df3,df4],axis='col')

x=make_df('AB',[0,1])
y=make_df('AB',[2,3])
y.index=x.index
print(x)
print(y)
print(pd.concat([x,y],keys=['x','y']))

df5=make_df('ABC',[1,2])
df6=make_df('BCD',[3,4])
print(df5)
print(df6)
print(pd.concat([df5,df6]))
print(pd.concat([df5,df6],join='inner'))
# Out:
#     A   B
# 1  A1  B1
# 2  A2  B2
#     A   B
# 3  A3  B3
# 4  A4  B4
#     A   B
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4
#     A   B
# 0  A0  B0
# 1  A1  B1
#     C   D
# 0  C0  D0
# 1  C1  D1
#     A   B
# 0  A0  B0
# 1  A1  B1
#     A   B
# 0  A2  B2
# 1  A3  B3
#       A   B
# x 0  A0  B0
#   1  A1  B1
# y 0  A2  B2
#   1  A3  B3
#     A   B   C
# 1  A1  B1  C1
# 2  A2  B2  C2
#     B   C   D
# 3  B3  C3  D3
# 4  B4  C4  D4
#      A   B   C    D
# 1   A1  B1  C1  NaN
# 2   A2  B2  C2  NaN
# 3  NaN  B3  C3   D3
# 4  NaN  B4  C4   D4
#     B   C
# 1  B1  C1
# 2  B2  C2
# 3  B3  C3
# 4  B4  C4

# %%
print(df1.append(df2))
## poco efficenty meglio fare concat

#merge
df1=pd.DataFrame({'employee':['Bob','Jake','Lisa','Sue'],
                 'group':['Accounting','Engi','Engi','HR']})

df2=pd.DataFrame({'employee': ['Lisa','Bob','Sue','Jake'],
                  'hire_data':[2004,2008,2012,2014]})

print(df1)
print(df2)
print(pd.merge(df1,df2))
df3=pd.merge(df1,df2)

df4=pd.DataFrame({'group':['Accounting','Engi','HR'],
                 'supervisor':['Carly','Guido','Steve']})
print(df3)
print(df4)
print(pd.merge(df3,df4))
# Out:
#   employee       group  hire_data
# 0      Bob  Accounting        NaN
# 1     Jake        Engi        NaN
# 2     Lisa        Engi        NaN
# 3      Sue          HR        NaN
# 0     Lisa         NaN     2004.0
# 1      Bob         NaN     2008.0
# 2      Sue         NaN     2012.0
# 3     Jake         NaN     2014.0
#   employee       group
# 0      Bob  Accounting
# 1     Jake        Engi
# 2     Lisa        Engi
# 3      Sue          HR
#   employee  hire_data
# 0     Lisa       2004
# 1      Bob       2008
# 2      Sue       2012
# 3     Jake       2014
#   employee       group  hire_data
# 0      Bob  Accounting       2008
# 1     Jake        Engi       2014
# 2     Lisa        Engi       2004
# 3      Sue          HR       2012
#   employee       group  hire_data
# 0      Bob  Accounting       2008
# 1     Jake        Engi       2014
# 2     Lisa        Engi       2004
# 3      Sue          HR       2012
#         group supervisor
# 0  Accounting      Carly
# ...

# %%
df5=pd.DataFrame({'group':['Accounting','Engi','HR','HR','Engi'],
                 'skills':['math','linux','coding','codder','diooo']})

print(df1)
print(df5)
print(pd.merge(df1,df5))

#167
# Out:
#   employee       group
# 0      Bob  Accounting
# 1     Jake        Engi
# 2     Lisa        Engi
# 3      Sue          HR
#         group  skills
# 0  Accounting    math
# 1        Engi   linux
# 2          HR  coding
# 3          HR  codder
# 4        Engi   diooo
#   employee       group  skills
# 0      Bob  Accounting    math
# 1     Jake        Engi   linux
# 2     Jake        Engi   diooo
# 3     Lisa        Engi   linux
# 4     Lisa        Engi   diooo
# 5      Sue          HR  coding
# 6      Sue          HR  codder

# %%
import pandas as pd
df6 = pd.DataFrame({'name':['Peter','Paul','Mary'],
                    'food':['fish','beans','bread']})

df7=pd.DataFrame({'name':['Mary','Joseph'],
                  'drink':['wine','beer']},
                   columns=['name','drink'])

#print(df6)
#print(df7)
print(pd.merge(df6,df7,how='inner'))
print(pd.merge(df6,df7,how='outer'))
print(pd.merge(df6,df7,how='left'))
print(pd.merge(df6,df7,how='right'))

df8=pd.DataFrame({'name':['Bob','Jake','Lisa','Sue'],
                  'rank':[1,2,3,4]})
df9=pd.DataFrame({'name':['Bob','Jake','Lisa','Sue'],
                  'rank':[3,1,4,2]})

print(pd.merge(df8,df9,on="name"))
print(pd.merge(df8,df9,on="name",suffixes=["_L","_R"]))
# Out:
#    name   food drink
# 0  Mary  bread  wine
#      name   food drink
# 0   Peter   fish   NaN
# 1    Paul  beans   NaN
# 2    Mary  bread  wine
# 3  Joseph    NaN  beer
#     name   food drink
# 0  Peter   fish   NaN
# 1   Paul  beans   NaN
# 2   Mary  bread  wine
#      name   food drink
# 0    Mary  bread  wine
# 1  Joseph    NaN  beer
#    name  rank_x  rank_y
# 0   Bob       1       3
# 1  Jake       2       1
# 2  Lisa       3       4
# 3   Sue       4       2
#    name  rank_L  rank_R
# 0   Bob       1       3
# 1  Jake       2       1
# 2  Lisa       3       4
# 3   Sue       4       2

# %%
state=pd.read_csv('state.csv.txt')
pop=pd.read_csv('population.txt')
abbr=pd.read_csv('abbr.txt')
print(pop.head())

merged=pd.merge(pop,abbr,how='outer',left_on='state/region',right_on="abbreviation")
#print(merged)
merged=merged.drop('abbreviation',1)
merged.isnull().any()

print(merged[merged['population'].isnull()])
print(merged.loc[merged['state'].isnull(),'state/region'].unique())
merged.loc[merged['state/region']=='PR','state']='Puerto Rico'
merged.loc[merged['state/region']=='USA','state']='United States'
merged.isnull().any()


final=pd.merge(merged,state,on='state',how='left')
final.head()

final.isnull().any()

final['state'][final['area (sq. mi)'].isnull()].unique()
final.dropna(inplace=True)
final.head()

data2010=final.query("year == 2010 & ages == 'total'")
data2010.head()

data2010.set_index('state',inplace=True)
density=data2010['population']/data2010['area (sq. mi)']

density.sort_values(ascending=False,inplace=True)
density.head()
density.tail()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0
#      state/region     ages  year  population state
# 2448           PR  under18  1990         NaN   NaN
# 2449           PR    total  1990         NaN   NaN
# 2450           PR    total  1991         NaN   NaN
# 2451           PR  under18  1991         NaN   NaN
# 2452           PR    total  1993         NaN   NaN
# 2453           PR  under18  1993         NaN   NaN
# 2454           PR  under18  1992         NaN   NaN
# 2455           PR    total  1992         NaN   NaN
# 2456           PR  under18  1994         NaN   NaN
# 2457           PR    total  1994         NaN   NaN
# 2458           PR    total  1995         NaN   NaN
# 2459           PR  under18  1995         NaN   NaN
# ...

# %%
import seaborn as sns
import numpy as np

planets=sns.load_dataset('planets')
planets.shape
planets.head()

rng=np.random.RandomState(42)
ser=pd.Series(rng.rand(5))
print(ser)
print(ser.sum())
print(ser.mean())
print(planets.dropna().describe())


#Groupby
df=pd.DataFrame({'key':['A','B','C','A','B','C'],
                 'data':range(6)},columns=['key','data'])
print(df)
print(df.groupby('key').sum())
print(planets.groupby('method')['orbital_period'].median())
print(planets.groupby('method')['year'].describe().unstack())
# Out:
# 0    0.374540
# 1    0.950714
# 2    0.731994
# 3    0.598658
# 4    0.156019
# dtype: float64
# 2.811925491708157
# 0.5623850983416314
#           number  orbital_period        mass    distance         year
# count  498.00000      498.000000  498.000000  498.000000   498.000000
# mean     1.73494      835.778671    2.509320   52.068213  2007.377510
# std      1.17572     1469.128259    3.636274   46.596041     4.167284
# min      1.00000        1.328300    0.003600    1.350000  1989.000000
# 25%      1.00000       38.272250    0.212500   24.497500  2005.000000
# 50%      1.00000      357.000000    1.245000   39.940000  2009.000000
# 75%      2.00000      999.600000    2.867500   59.332500  2011.000000
# max      6.00000    17337.500000   25.000000  354.000000  2014.000000
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5
#      data
# key
# A       3
# B       5
# C       7
# method
# Astrometry                         631.180000
# ...

# %%
rng=np.random.RandomState(0)
df=pd.DataFrame({'key':['A','B','C','A','B','C'],
                 'data1': range(6),
                 'data2': rng.randint(0,10,6)},
                 columns=['key','data1','data2'])

print(df)
print(df.groupby('key').aggregate(['min',np.median,max]))
print(df.groupby('key').aggregate({'data1':'min',
                                   'data2':'max'}))

#filtering

def filter_func(x):
    return x['data2'].std()>4

def norm_by_data2(x):
    x['data1']/=x['data2'].sum()
    return x
    
print(df.groupby('key').std())
print(df.groupby('key').filter(filter_func))
print(df.groupby('key').transform(lambda x: x-x.mean()))
print(df.groupby('key').transform(lambda x: x*2))
print(df.groupby('key').apply(norm_by_data2))
print(df.groupby([0,1,0,1,2,0]).sum())

df2=df.set_index('key')
mapping={'A':'Record_A','B':'Generico','C':'Generico'}
df2.groupby(mapping).sum()
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9
#     data1            data2
#       min median max   min median max
# key
# A       0    1.5   3     3    4.0   5
# B       1    2.5   4     0    3.5   7
# C       2    3.5   5     3    6.0   9
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      9
#        data1     data2
# key
# A    2.12132  1.414214
# B    2.12132  4.949747
# C    2.12132  4.242641
#   key  data1  data2
# 1   B      1      0
# 2   C      2      3
# 4   B      4      7
# 5   C      5      9
#    data1  data2
# 0   -1.5    1.0
# 1   -1.5   -3.5
# 2   -1.5   -3.0
# 3    1.5   -1.0
# 4    1.5    3.5
# 5    1.5    3.0
#    data1  data2
# 0      0     10
# 1      2      0
# 2      4      6
# 3      6      6
# 4      8     14
# 5     10     18
#   key     data1  data2
# 0   A  0.000000      5
# 1   B  0.142857      0
# ...

# %%
decade=10* (planets['year']//10)
decade=decade.astype(str)+'s'
decade.name='decade'
planets.groupby(['method',decade])['number'].sum().unstack().fillna(0)
# Out:
# decade                         1980s  1990s  2000s  2010s
# method
# Astrometry                       0.0    0.0    0.0    2.0
# Eclipse Timing Variations        0.0    0.0    5.0   10.0
# Imaging                          0.0    0.0   29.0   21.0
# Microlensing                     0.0    0.0   12.0   15.0
# Orbital Brightness Modulation    0.0    0.0    0.0    5.0
# Pulsar Timing                    0.0    9.0    1.0    1.0
# Pulsation Timing Variations      0.0    0.0    1.0    0.0
# Radial Velocity                  1.0   52.0  475.0  424.0
# Transit                          0.0    0.0   64.0  712.0
# Transit Timing Variations        0.0    0.0    0.0    9.0

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
print(titanic.groupby('sex')[['survived']].mean())
print(titanic.groupby(['sex','class'])['survived'].mean())
age=pd.cut(titanic['age'],[0,18,45,80])
print(age)
titanic.pivot_table('survived',['sex',age],'class')

fare=pd.qcut(titanic['fare'],2)
titanic.pivot_table('survived',['sex',age],[fare,'class'])

titanic.pivot_table(index='sex',columns='class',
                    aggfunc={'survived':sum, 'fare':'mean'})
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908
# sex     class
# female  First     0.968085
#         Second    0.921053
#         Third     0.500000
# male    First     0.368852
#         Second    0.157407
#         Third     0.135447
# Name: survived, dtype: float64
# 0      (18.0, 45.0]
# 1      (18.0, 45.0]
# 2      (18.0, 45.0]
# 3      (18.0, 45.0]
# 4      (18.0, 45.0]
#            ...
# 886    (18.0, 45.0]
# 887    (18.0, 45.0]
# 888             NaN
# 889    (18.0, 45.0]
# 890    (18.0, 45.0]
# Name: age, Length: 891, dtype: category
# Categories (3, interval[int64]): [(0, 18] < (18, 45] < (45, 80]]
#               fare                       survived
# class        First     Second      Third    First Second Third
# sex
# female  106.125798  21.970121  16.118810       91     70    72
# male     67.226127  19.741782  12.661633       45     17    47

# %%
import matplotlib.pyplot as plt
births=pd.read_csv('birth.txt')
births.head()

births['decade']=10*(births['year']//10)
births.head()
births.pivot_table('births',index='decade',columns='gender',aggfunc='sum')
sns.set()

births.pivot_table('births',index='year', columns='gender',aggfunc='sum').plot()
plt.ylabel('total birth for year')


quartiles=np.percentile(births['births'],[25,50,75])
mu=quartiles[1]

sig=0.74* (quartiles[2]-quartiles[0]) 

births=births.query('(births > @mu - 5 * @sig) & (births < @mu +5 *@sig)')
births['day']=births['day'].astype(int)

births.index=pd.to_datetime(10000* births.year +
                            100 * births.month + 
                            births.day, format='%Y%m%d')

births['dayofweek']=births.index.dayofweek
births.pivot_table('births',index='dayofweek',
                  columns='decade', aggfunc='mean').plot()

plt.gca().set_xticklabels(['Mon','Tues','Wed','Thurs','Fri','Sat','Sun'])
plt.ylabel('mean births by day')
# Out:
# Text(0, 0.5, 'mean births by day')

# %%
births_by_date=births.pivot_table('births',
                                  [births.index.month, births.index.day])
births_by_date.index=[pd.datetime(2012,month,day)
                      for (month,day) in births_by_date.index]

fig,ax =plt.subplots(figsize=(12,4))
births_by_date.plot(ax=ax)
# Out:
# <ipython-input-95-115b1a7e7a32>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   births_by_date.index=[pd.datetime(2012,month,day)

# %%
monte=pd.Series(['Graham Chapman','John Cleese','Terry Gilliam',
                'Eric Idle', 'Terry Jones','Michael Palin'])

full_monte=pd.DataFrame({'name':monte,
                         'info':['B|C|D','B|D','A|C','B|D','B|C','B|C|D']})
full_monte['info'].str.get_dummies('|')
# Out:
#    A  B  C  D
# 0  0  1  1  1
# 1  0  1  0  1
# 2  1  0  1  0
# 3  0  1  0  1
# 4  0  1  1  0
# 5  0  1  1  1

# %%
from datetime import datetime
datetime(year=2015,month=7,day=4)

from dateutil import parser

date=parser.parse("4th of July, 2015")
date

date=np.array('2015-07-04',dtype=np.datetime64)
print(date)
print(date+np.arange(15))
date=pd.to_datetime("4th of July, 2015")
print(date)

date.strftime('%A')
date + pd.to_timedelta(np.arange(12),'D')
index=pd.DatetimeIndex(['2014-07-04','2014-08-04',
                         '2015-07-04', '2015-08-04'])
date=pd.Series([0,1,2,3],index=index)
print(date)
print(date['2014-07-04':'2015-07-04'])

dates=pd.to_datetime([datetime(2015,7,3), '4th of July, 2015','2015-Jul-6','07-07-2015','20150708'])
dates.to_period('D')
dates-dates[0]
print(dates)
pd.date_range('2015-07-03','2015-07-10')
pd.date_range('2015-07-03', periods=8)
pd.date_range('2015-07-03',periods=8,freq='H')
pd.period_range('2015-07',periods=10,freq='M')
pd.timedelta_range(0,periods=10,freq='H')

pd.timedelta_range(0,periods=9,freq="2H30T")

from pandas.tseries.offsets import BDay


pd.date_range('2015-07-01', periods=5,freq=BDay())
# Out:
# 2015-07-04
# ['2015-07-04' '2015-07-05' '2015-07-06' '2015-07-07' '2015-07-08'
#  '2015-07-09' '2015-07-10' '2015-07-11' '2015-07-12' '2015-07-13'
#  '2015-07-14' '2015-07-15' '2015-07-16' '2015-07-17' '2015-07-18']
# 2015-07-04 00:00:00
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-04    2
# 2015-08-04    3
# dtype: int64
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-04    2
# dtype: int64
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-06', '2015-07-07',
#                '2015-07-08'],
#               dtype='datetime64[ns]', freq=None)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-122-fc725dba4795> in <module>
#      34
#      35 from pandas.tseries.offsets import BDay
# ---> 36 from pandas_datareader import data
#      37
#      38 pd.date_range('2015-07-01', periods=5,freq=BDay())
#
# ModuleNotFoundError: No module named 'pandas_datareader'
